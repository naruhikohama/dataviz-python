# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import datetime

# %%
housing_raw = pd.read_csv('data/housing_data.csv',
                          parse_dates=['period_begin', 'period_end'],
                          dtype={'total_homes_sold':'Int32', 'region_name':'category'})

# %%
housing_raw.head()
# Out:
#           region_name period_begin period_end  total_homes_sold  inventory  \
# 0  Appling County, GA   2020-04-27 2020-07-19              <NA>        1.0
# 1   Tooele County, UT   2018-08-27 2018-11-18               325        NaN
# 2  Johnson County, TX   2019-09-23 2019-12-15               577      717.0
# 3   Holmes County, OH   2017-10-09 2017-12-31                22       52.0
# 4  Madison County, FL   2017-01-09 2017-04-02                12       54.0
#
#    active_listings  age_of_inventory  median_active_list_price  \
# 0              1.0             222.7                  136195.8
# 1              NaN               NaN                       NaN
# 2            778.0              63.0                  268737.6
# 3             54.0             109.4                  115308.3
# 4             55.0             151.2                  158062.5
#
#    months_of_supply
# 0               NaN
# 1               NaN
# 2         17.095583
# 3         34.050000
# 4         38.300000

# %%
housing_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622339 entries, 0 to 622338
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   region_name               622339 non-null  category
#  1   period_begin              622339 non-null  datetime64[ns]
#  2   period_end                622339 non-null  datetime64[ns]
#  3   total_homes_sold          567839 non-null  Int32
#  4   inventory                 616247 non-null  float64
#  5   active_listings           616905 non-null  float64
#  6   age_of_inventory          616247 non-null  float64
#  7   median_active_list_price  616513 non-null  float64
#  8   months_of_supply          561319 non-null  float64
# dtypes: Int32(1), category(1), datetime64[ns](2), float64(5)
# memory usage: 37.5 MB

# %%
ca_housing = (housing_raw
              .loc[(housing_raw['region_name'].str.contains('CA'))]
              .assign(region_name = housing_raw['region_name'].str[0:-11]))

# %%
ca_housing.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15228 entries, 6 to 622302
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   region_name               15228 non-null  object
#  1   period_begin              15228 non-null  datetime64[ns]
#  2   period_end                15228 non-null  datetime64[ns]
#  3   total_homes_sold          14841 non-null  Int32
#  4   inventory                 15217 non-null  float64
#  5   active_listings           15218 non-null  float64
#  6   age_of_inventory          15217 non-null  float64
#  7   median_active_list_price  15208 non-null  float64
#  8   months_of_supply          14829 non-null  float64
# dtypes: Int32(1), datetime64[ns](2), float64(5), object(1)
# memory usage: 1.9 MB

# %%
ca_housing.head()
# Out:
#     region_name period_begin period_end  total_homes_sold  inventory  \
# 6    Sacramento   2020-06-22 2020-09-13              5107     1729.0
# 164      Nevada   2018-09-03 2018-11-25               529      480.0
# 252  Stanislaus   2017-06-05 2017-08-27              1572     1042.0
# 293      Tehama   2020-01-20 2020-04-12               102      241.0
# 304  Stanislaus   2017-11-13 2018-02-04              1200      797.0
#
#      active_listings  age_of_inventory  median_active_list_price  \
# 6             2206.0              27.5                  445540.9
# 164            517.0              71.4                  557508.3
# 252           1193.0              38.8                  320660.0
# 293            252.0              99.2                  297979.1
# 304            907.0              56.5                  330049.9
#
#      months_of_supply
# 6            5.235794
# 164         12.165607
# 252          9.212632
# 293         31.530228
# 304          9.744362

# %%
ca_housing_pivot = ca_housing.pivot_table(index='period_begin',
                                          columns='region_name',
                                          values='median_active_list_price').assign(
                                            CA_average = lambda x: x.mean(axis = 1)
                                          )

# %%
ca_housing_pivot.head()
# Out:
# region_name    Alameda    Alpine    Amador     Butte  Calaveras    Colusa  \
# period_begin
# 2017-01-02    730602.5  317541.6  408570.6  291315.3   503458.3  339075.0
# 2017-01-09    736230.0  324125.0  408566.4  292348.2   517645.8  340291.6
# 2017-01-16    742021.6  330708.3  408483.2  293514.9   524108.3  340291.6
# 2017-01-23    748271.7  341458.3  408404.0  294619.1   536408.3  341958.3
# 2017-01-30    753938.4  355541.6  407079.0  295527.4   543704.1  344041.6
#
# region_name   Contra Costa  El Dorado    Fresno     Glenn  ...  Stanislaus  \
# period_begin                                               ...
# 2017-01-02        603901.2   557404.1  251850.0  237145.8  ...    300302.0
# 2017-01-09        610701.2   563658.3  253016.6  237145.8  ...    301900.0
# 2017-01-16        616534.5   565908.3  254187.5  237841.6  ...    303858.3
# 2017-01-23        621617.8   567158.3  255854.1  238041.6  ...    306350.0
# ...

# %%
ca_housing_markets = ca_housing_pivot.loc[:, ['San Francisco',
                                              'Los Angeles',
                                              'San Diego',
                                              'CA_average']]
ca_housing_markets
# Out:
# region_name   San Francisco  Los Angeles  San Diego     CA_average
# period_begin
# 2017-01-02        1229018.7     611561.0   618570.8  492258.437736
# 2017-01-09        1233393.7     614061.0   621737.5  493710.639623
# 2017-01-16        1239977.0     617311.0   625820.8  495369.416981
# 2017-01-23        1247977.0     620644.3   629491.6  497191.662264
# 2017-01-30        1253310.4     624541.6   632824.0  499286.207547
# ...                     ...          ...        ...            ...
# 2022-03-28        1289875.0     906783.0   901649.6  686582.361818
# 2022-04-04        1289916.6     906783.1   902899.8  687180.140000
# 2022-04-11        1290250.0     906782.4   902899.8  687730.720000
# 2022-04-18        1294000.0     906786.5   901983.0  688234.945455
# 2022-04-25        1295750.0     906744.9   901916.4  688836.841818
#
# [278 rows x 4 columns]

# %%
fig, ax = plt.subplots()

fig.set_figheight(6)
fig.set_figwidth(10)

# ax.plot(ca_housing_markets)

ax.plot(ca_housing_markets.index, ca_housing_markets['San Francisco'], label = 'SF')
ax.plot(ca_housing_markets.index, ca_housing_markets['Los Angeles'], label = 'LA')

fig.suptitle("House Prices", fontsize = 16)
ax.set_title('CA Markets 2017 - 2022', fontsize=14)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Price (Millions)', fontsize=12)

ax.legend(bbox_to_anchor = (.6, -.1), ncol = 2, frameon = False)

plt.show()

# %%
fig, ax = plt.subplots()

fig.set_figheight(6)
fig.set_figwidth(10)

# ax.plot(ca_housing_markets)

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['San Francisco'], 
        label = 'SF',
        color = 'green',
        linewidth = 2)

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['Los Angeles'], 
        label = 'LA',
        color = 'purple',
        linewidth = 3,
        linestyle = 'dashed')

fig.suptitle("House Prices", fontsize = 16)
ax.set_title('CA Markets 2017 - 2022', fontsize=14)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Price (Millions)', fontsize=12)

ax.legend(bbox_to_anchor = (.6, -.1), ncol = 2, frameon = False)

plt.show()

# %%
fig, ax = plt.subplots()

fig.set_figheight(6)
fig.set_figwidth(10)

# ax.plot(ca_housing_markets)

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['San Francisco'] / 1_000_000, 
        label = 'SF',
        color = 'green',
        linewidth = 2)

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['Los Angeles'] / 1_000_000, 
        label = 'LA',
        color = 'purple',
        linewidth = 2)

fig.suptitle("House Prices", fontsize = 16)
ax.set_title('CA Markets 2017 - 2022', fontsize=14)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Price (Millions)', fontsize=12)

ax.legend(bbox_to_anchor = (.6, -.1), ncol = 2, frameon = False)
ax.set_ylim(0, 1.6)
ax.set_xlim(datetime.date(2016, 12, 1), datetime.date(2022,6,1))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

# ax.plot(ca_housing_markets)

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['San Francisco'] / 1_000_000, 
        label = 'SF',
        color = 'green',
        linewidth = 2)

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['Los Angeles'] / 1_000_000, 
        label = 'LA',
        color = 'purple',
        linewidth = 2)

fig.suptitle("House Prices", fontsize = 16)
ax.set_title('CA Markets 2017 - 2022', fontsize=14)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Price (Millions)', fontsize=12)

ax.legend(loc = 'upper right', ncol = 2, frameon = False)
ax.set_ylim(0, 1.6)
ax.set_xlim(datetime.date(2016, 12, 1), datetime.date(2022,6,1))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

# ax.plot(ca_housing_markets)

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['San Francisco'] / 1_000_000, 
        label = 'SF',
        color = 'green',
        linewidth = 2)

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['Los Angeles'] / 1_000_000, 
        label = 'LA',
        color = 'purple',
        linewidth = 2)

fig.suptitle("House Prices", fontsize = 16)
ax.set_title('CA Markets 2017 - 2022', fontsize=14)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Price (Millions)', fontsize=12)

ax.legend(loc = 'upper right', ncol = 2, frameon = False)
ax.set_ylim(0, 1.6)
ax.set_xlim(datetime.date(2016, 12, 1), datetime.date(2022,6,1))

ax.set_xticks(ca_housing_markets.index[::24])
plt.xticks(rotation = 45)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

# ax.plot(ca_housing_markets)

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['San Francisco'] / 1_000_000, 
        label = 'SF',
        color = 'green',
        linewidth = 2)

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['Los Angeles'] / 1_000_000, 
        label = 'LA',
        color = 'purple',
        linewidth = 2)

fig.suptitle("House Prices", fontsize = 16)
ax.set_title('CA Markets 2017 - 2022', fontsize=14)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Price (Millions)', fontsize=12)

ax.legend(loc = 'upper right', ncol = 2, frameon = False)
ax.set_ylim(0, 1.6)
ax.set_xlim(datetime.date(2016, 12, 1), datetime.date(2022,6,1))

plt.show()

# %%
datetime.datetime(2018, 3, 21) - datetime.datetime(1970, 1, 1)
# Out:
# datetime.timedelta(days=17611)

# %%
fig, ax = plt.subplots(figsize = (10, 7))

ax.plot(
    ca_housing_markets.index,
    ca_housing_markets['San Francisco'] / 1_000_000,
    label = 'San Francisco',
    color = 'green',
)

ax.plot(
    ca_housing_markets.index,
    ca_housing_markets['Los Angeles'] / 1_000_000,
    label = 'Los Angeles',
    color = 'purple',
)

ax.set_title('Housing prices in CA Markets 2017-2022', fontsize = 12)
ax.set_xlabel("Year")
ax.set_ylabel("Price (Millions)")
ax.set_ylim(0, 1.6)

line_max_y = ca_housing_markets[ca_housing_markets.index == datetime.datetime(2018, 3, 5)][['San Francisco', 'Los Angeles']].values.max() / 1_000_000

ax.axvline(datetime.datetime(2018, 3, 5), ymin= 0, ymax = line_max_y / 1.6, color = 'grey', ls = 'dashed', label = 'random date')

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 6))

ax.plot(ca_housing_markets.index, 
        ca_housing_markets['San Francisco'] / 1_000_000,
        label = 'San Francisco',
        color = 'green')

ax.plot(ca_housing_markets.index,
        ca_housing_markets['Los Angeles'] / 1_000_000,
        label = 'Los Angeles',
        color = 'purple')

ax.set_xlabel('Year')
ax.set_ylabel('Price (Millions)')

ax.set_ylim(0, 1.6)
ax.legend()

max_y = ca_housing_markets[ca_housing_markets.index == datetime.datetime(2020, 3, 9)].values.max() / 1_000_000

ax.axvline(datetime.datetime(2020, 3, 9), ymin = 0, ymax = max_y / 1.6, color = 'grey', ls = 'dashed')

fig.text(0.6, 0.6, "Prices starts to drop in\nSan Francisco from this date", fontname = 'monospace')

ax.set_title("Housing Prices in CA Markets 2017-2022", fontsize = 14)

plt.show()

# %%
ca_housing_markets[ca_housing_markets.index == datetime.datetime(2020, 3, 9)].values.max()
# Out:
# 1500166.6

# %% [markdown]
# ## Stacked line charts

# %%
fig, ax = plt.subplots(figsize = (10, 6))

ax.stackplot(
    ca_housing_pivot.index,
    ca_housing_pivot['Los Angeles'],
    ca_housing_pivot['San Diego'],
    ca_housing_pivot['San Francisco'],
    labels = ['Los Angeles', 'San Diego', 'San Francisco'],
    colors = ['grey', 'green', 'orange']
)


ax.legend()

plt.show()

# %% [markdown]
# ## Dual axis charts

# %%
ca_housing2 = (
    housing_raw
    .loc[housing_raw['region_name'].str.contains("CA")]
    .assign(region_name = housing_raw['region_name'].str[0:-11])
    .set_index('period_begin')
    .sort_index()
)

# %%
ca_housing2.head()
# Out:
#              region_name period_end  total_homes_sold  inventory  \
# period_begin
# 2017-01-02          Mono 2017-03-26                97      153.0
# 2017-01-02          Yolo 2017-03-26               336      234.0
# 2017-01-02    Stanislaus 2017-03-26              1192      912.0
# 2017-01-02        Shasta 2017-03-26                 7       17.0
# 2017-01-02        Lassen 2017-03-26                 2        5.0
#
#               active_listings  age_of_inventory  median_active_list_price  \
# period_begin
# 2017-01-02              161.0              89.7                  450745.8
# 2017-01-02              272.0              48.5                  447859.2
# 2017-01-02             1043.0              55.3                  300302.0
# 2017-01-02               18.0             147.5                  489020.8
# 2017-01-02                5.0              98.8                  198750.0
#
#               months_of_supply
# period_begin
# 2017-01-02           21.208631
# ...

# %%
sd_dual = (
    ca_housing2
    .loc[ca_housing2['region_name'] == 'San Diego', ['inventory', 'median_active_list_price']]
)

# %%
fig, ax = plt.subplots()

ax.plot(sd_dual['inventory'], label = 'inventory')
ax.set_ylim(0, 10_000)

ax2 = ax.twinx()

ax2.plot(sd_dual['median_active_list_price'], label = 'price', color = 'orange')
ax2.set_ylim(0, 1_000_000)

fig.legend(bbox_to_anchor = (0.35, 0.28))
plt.show()
